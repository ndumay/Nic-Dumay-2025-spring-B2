# %%
# Trying my best a learn how to use GitHub and Jupyter Notebooks. 
# Read that an appendix should be created for use of ChatGPT or other AI Assistance.
# I want to make sure that I am following the rules. Please advise if I should be doing anything differently.


# BU AI Use Policy: https://www.bu.edu/cds-faculty/culture-community/gaia-policy/
# BU APA Formatted AI Use Citation: "OpenAI. (2024). Transcript of conversation with problem-solving solutions. Unpublished interaction transcript. Retrieved from OpenAI’s ChatGPT platform. In accordance with Boston University GAIA policy."


# BU AI Use Citation Requirements:
# b) ChatGPT (Subscription) 
# c) Primarily will be using ChatGPT to prime myself for how to solution for problems within an assignment, what libraries most help with solving the problem, and then walking me through the steps to understanding how to get to the solution. ChatGPT, is helping me bridge a gap in my understand of converting course concepts to code;
# d) AI is primarily being used as a preceptor that translates teachings information into to practical development knowledge to better understand the steps to the solution, learn optimal development to a given problem to form wisdom;

# Initial Dialog: 
# Asked for help with a homework assignment using GitHub Codespaces, Python, and Jupyter Notebooks. 
# Provided libraries to be used and mentioned that I would need to cite the use of ChatGPT in the appendix.
# Requested help in solving problems seaking step by step instructional breakdown for learning for 10 questions.


# a) the entire exchange, highlighting the most relevant sections;

# Problem Statements and Solution Steps Summary with Detailed Explanations

# **Transcript Summary**

# Transcript Summary of Conversation

# User uploaded a Jupyter Notebook file and requested help with answering questions 
# in sections 2 (Weekly Graph Question), 3 (Homework - Reproducing Pair Plot Graphs), 
# and 4 (Storytelling with Data Plot) using Python.

# We identified key requirements:
# - Bivariate Analysis knowledge
# - Generating and analyzing scatter plots, histograms, and time-series data
# - Creating and formatting visualizations to match the book "Storytelling with Data"

# --- Section 2: Weekly Graph Question ---
# - Discussed the importance of correlation in pair plots.
# - Selected the most informative graphs for visualizing chemical relationships.
# - Recommended methods to improve clarity (e.g., transparency, regression lines).
# - Explained why fitting a line/curve may not always be necessary.

# --- Section 3: Homework - Reproducing Pair Plot Graphs ---
# - Created scatter plots with two and three cloud clusters.
# - Generated histograms with a tailing-off effect.
# - Developed a line plot to represent U-shaped soft drink sales trends.
# - Designed an area plot for competing soft drink brands (one increasing then decreasing, and vice versa).

# # Python code for scatter plot (two vertically separated clouds)
# import numpy as np
# import matplotlib.pyplot as plt
# x1 = np.random.normal(30, 5, 50)
# y1 = np.random.normal(40, 5, 50)
# x2 = np.random.normal(70, 5, 50)
# y2 = np.random.normal(80, 5, 50)
# plt.scatter(np.concatenate([x1, x2]), np.concatenate([y1, y2]))
# plt.show()

# - Verified correlation for the cloud scatter plot.
# - Determined that the overall correlation (~0.55) was moderate, meaning there was some relationship but not perfect linearity.

# # Python code for correlation analysis
# import pandas as pd
# df = pd.DataFrame({'data_A': np.concatenate([x1, x2]), 'data_B': np.concatenate([y1, y2])})
# print(df.corr())

# --- Section 4: Storytelling with Data Plot ---
# - Selected a bar chart representing soda sales trends.
# - Followed best practices from "Storytelling with Data" (clean layout, strategic bolding, proper spacing).
# - Refined annotations and color emphasis to enhance storytelling.

# # Python code for an improved horizontal bar chart using soda sales data
# import matplotlib.pyplot as plt
# brands = ["Brand A - Peak", "Brand B - Peak", "Brand A - Decline", "Brand B - Decline", "Brand A - Recovery", "Brand B - Recovery"]
# sales = [80, 75, 50, 45, 40, 35]
# plt.barh(brands[::-1], sales[::-1], color="gray")
# plt.title("Soda Sales Performance: Peaks and Declines", fontsize=14, fontweight="bold")
# plt.xlabel("% of Total Sales")
# plt.show()

# - Adjusted a histogram to match the book’s format by fine-tuning peak width, tailing effect, and axis labels.

# # Python code for a refined histogram
# data = np.concatenate([np.random.normal(0, 0.7, 16000), np.random.normal(0, 1.8, 5000), np.random.normal(0, 3.2, 2500)])
# plt.hist(data, bins=np.arange(-4.5, 4.5, 0.25), color="gray", edgecolor="black")
# plt.title("Histogram with Tailing Off Effect", fontsize=14, fontweight="bold")
# plt.show()

# - Fixed a "NameError" in the area plot by defining the missing `days` variable.

# # Python code for an area plot with two competing soft drink brands
# days = np.arange(1, 366)
# brand_1_sales = 150 + 50 * np.sin((days / 365) * 2 * np.pi) + np.random.normal(0, 5, len(days))
# brand_2_sales = 150 + 50 * np.cos((days / 365) * 2 * np.pi) + np.random.normal(0, 5, len(days))
# plt.fill_between(days, brand_1_sales, alpha=0.5, label="Brand A Sales")
# plt.fill_between(days, brand_2_sales, alpha=0.5, label="Brand B Sales")
# plt.legend()
# plt.show()

# - Further refined histogram accuracy to match bar heights and distribution more closely.
# - Finalized all requested visualizations to align with "Storytelling with Data" best practices.

# End of Transcript Summary
