# %% [markdown]
# # Week 2 - Preprocessing, part 2
#
# # 1. Lesson: None

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# The Storytelling With Data book mentions planning on a "Who, What, and How" for your data story.  Write down a possible Who, What, and How for your data, using the ideas in the book.

# %% [markdown]
# Who: Businesses, Sale Leads
#
# What: The progress of Sale Rep. How muc their deal was, at what stage they are in the pipeline, their lead creation and closing date, the quality of the lead, source of the lead, probabrlty of closing the deal and any other notes on the deal.
#
# How: This data is to mimic a CRM from SalesForce or Hubspot in which Sale Leads and Managers can look at which sales reps are working.
# Furthermore, there the second set of code will be a generated transcript of perhaps a typical gong sales call might entail. In addition to the information in the CRM, this would allow the transciprt to depict the the tone and the sentiment of the sale reps.

# %% [markdown]
# # 3. Homework - work with your own data

# %%
import random
import pandas as pd
from datetime import datetime
from datetime import timedelta
import numpy as np
from random import choice, randint
random.seed(42)

customers = list(range(10000,99999))
sales_reps = ['Rep_A', 'Rep_B', 'Rep_C', 'Rep_D']
stages = ['Prospecting', 'Qualification', 'Proposal', 'Negotiation', 'Closed Won', 'Closed Lost']
lead_sources = ['Web', 'Referral', 'Social Media', 'Direct Mail', 'Email Campaign']
lead_quality = ['High', 'Medium', 'Low']
close_dates = [datetime.today() - timedelta(days=randint(1, 365)) for _ in range(5)]

num_records = 100  

data = {
    'Customer_ID': [choice(customers) for _ in range(num_records)],
    'Sales_Rep': [choice(sales_reps) for _ in range(num_records)],
    'Deal_Value': [randint(1000, 50000) for _ in range(num_records)],
    'Stage': [choice(stages) for _ in range(num_records)],
    'Close_Date': [choice(close_dates) for _ in range(num_records)],
    'Lead_Source': [choice(lead_sources) for _ in range(num_records)],
    'Lead_Quality': [choice(lead_quality) for _ in range(num_records)],
    'Lead_Creation_Date': [datetime.today() - timedelta(days=randint(10, 100)) for _ in range(num_records)],
    'Deal_Probability': [round(np.random.uniform(0.2, 1.0), 2) for _ in range(num_records)],
    'Deal_Notes': ['Potential high-value deal' if np.random.rand() > 0.5 else 'Needs more nurturing' for _ in range(num_records)],
}


df_crm = pd.DataFrame(data)

df_crm.to_csv('crm_sales_data.csv', index=False)

print("First 5 records of the CRM Sales Dataset:")
print(df_crm.head())
# Out:
# First 5 records of the CRM Sales Dataset:
#    Customer_ID Sales_Rep  Deal_Value          Stage  \
# 0        39256     Rep_B       24219    Closed Lost
# 1        28289     Rep_D       28759    Closed Lost
# 2        23434     Rep_D       27941       Proposal
# 3        98696     Rep_D       31606  Qualification
# 4        81482     Rep_B       48780       Proposal
#
#                   Close_Date     Lead_Source Lead_Quality  \
# 0 2024-12-13 03:21:31.677180     Direct Mail       Medium
# 1 2024-03-18 03:21:31.677030     Direct Mail       Medium
# 2 2025-01-27 03:21:31.677188     Direct Mail       Medium
# 3 2024-10-06 03:21:31.677198        Referral          Low
# 4 2024-09-21 03:21:31.677193  Email Campaign          Low
#
#           Lead_Creation_Date  Deal_Probability                 Deal_Notes
# 0 2024-11-11 03:21:31.678097              0.87  Potential high-value deal
# 1 2024-12-30 03:21:31.678115              0.99       Needs more nurturing
# ...

# %%
df_crm
# Out:
#     Customer_ID Sales_Rep  Deal_Value          Stage  \
# 0         39256     Rep_B       24219    Closed Lost
# 1         28289     Rep_D       28759    Closed Lost
# 2         23434     Rep_D       27941       Proposal
# 3         98696     Rep_D       31606  Qualification
# 4         81482     Rep_B       48780       Proposal
# ..          ...       ...         ...            ...
# 95        45093     Rep_D       38042       Proposal
# 96        18675     Rep_B       35261       Proposal
# 97        37653     Rep_A       21733    Prospecting
# 98        84341     Rep_A       18089       Proposal
# 99        51245     Rep_D       14386  Qualification
#
#                    Close_Date     Lead_Source Lead_Quality  \
# 0  2024-12-13 03:21:31.677180     Direct Mail       Medium
# 1  2024-03-18 03:21:31.677030     Direct Mail       Medium
# 2  2025-01-27 03:21:31.677188     Direct Mail       Medium
# 3  2024-10-06 03:21:31.677198        Referral          Low
# ...

# %%
import pandas as pd
import numpy as np
from random import choice, randint
from datetime import datetime, timedelta

call_ids = list(range(50000,99999))
speakers = ['Rep_A', 'Rep_B', 'Rep_C', 'Rep_D', 'Customer01','Customer02']
sentiments = ['Positive', 'Neutral', 'Negative']
keywords = ['Pricing', 'Product Features', 'Support', 'Onboarding', 'Objections', 'Renewal', 'Discount', 'Demo', 'Integration', 'Competitor']
transcripts = [
    "I think the product is a great fit for our needs.",
    "Could you clarify how the integration works?",
    "I'm worried about the pricing, it's higher than I expected.",
    "Can we get a discount if we sign up for a longer term?",
    "How does the onboarding process look?",
    "I'm not sure about the customer support response time.",
    "The features look impressive, but I need more details on integration.",
    "Are there any case studies you can share with us?",
    "The product is good, but we're also looking at a competitor."
]


num_records = 50 

data = {
    'Call_ID': [choice(call_ids) for _ in range(num_records)],
    'Timestamp': [datetime.today() - timedelta(minutes=randint(0, 1440)) for _ in range(num_records)],  # Random timestamps within the last day
    'Speaker': [choice(speakers) for _ in range(num_records)],
    'Transcript': [choice(transcripts) for _ in range(num_records)],
    'Sentiment': [choice(sentiments) for _ in range(num_records)],
    'Keywords': [', '.join(np.random.choice(keywords, size=randint(1, 3), replace=False)) for _ in range(num_records)],
    'Duration': [randint(10, 180) for _ in range(num_records)],  # Random duration between 10s to 180s
}


df_gong_transcripts = pd.DataFrame(data)

df_gong_transcripts.to_csv('gong_transcript_data.csv', index=False)

print("First 5 records of the Gong Transcript Dataset:")
print(df_gong_transcripts.head())
# Out:
# First 5 records of the Gong Transcript Dataset:
#    Call_ID                  Timestamp     Speaker  \
# 0    96062 2025-02-08 07:46:31.937205       Rep_A
# 1    79736 2025-02-08 17:39:31.937245       Rep_B
# 2    67754 2025-02-08 11:20:31.937264       Rep_B
# 3    70094 2025-02-08 11:01:31.937269       Rep_B
# 4    66475 2025-02-08 12:19:31.937274  Customer01
#
#                                           Transcript Sentiment  \
# 0  The features look impressive, but I need more ...   Neutral
# 1              How does the onboarding process look?   Neutral
# 2  The product is good, but we're also looking at...  Positive
# 3  The product is good, but we're also looking at...  Positive
# 4  Are there any case studies you can share with us?  Negative
#
#                            Keywords  Duration
# 0                           Renewal        19
# 1             Discount, Integration        42
# 2                          Discount       138
# ...

# %%
df_gong_transcripts
# Out:
#     Call_ID                  Timestamp     Speaker  \
# 0     96062 2025-02-08 07:46:31.937205       Rep_A
# 1     79736 2025-02-08 17:39:31.937245       Rep_B
# 2     67754 2025-02-08 11:20:31.937264       Rep_B
# 3     70094 2025-02-08 11:01:31.937269       Rep_B
# 4     66475 2025-02-08 12:19:31.937274  Customer01
# 5     65108 2025-02-08 15:44:31.937279       Rep_A
# 6     57907 2025-02-08 21:04:31.937284       Rep_B
# 7     97270 2025-02-09 01:36:31.937290       Rep_A
# 8     62621 2025-02-08 18:44:31.937296       Rep_D
# 9     70679 2025-02-08 11:03:31.937303       Rep_D
# 10    57835 2025-02-08 23:28:31.937308  Customer02
# 11    98685 2025-02-09 01:08:31.937313  Customer01
# 12    85118 2025-02-08 13:41:31.937318       Rep_D
# 13    99950 2025-02-08 10:34:31.937322       Rep_C
# 14    95230 2025-02-09 00:50:31.937326       Rep_A
# 15    62133 2025-02-08 07:40:31.937330       Rep_B
# 16    62552 2025-02-08 05:52:31.937334       Rep_C
# ...

# %% [markdown]
# This week, you will do the same types of exercises as last week, but you should use your own datasets that you found last semester.
#
# ### Here are some types of analysis you can do  Use Google, documentation, and ChatGPT to help you:
#
# - Summarize the datasets using info() and describe()
#
# - Are there any duplicate rows?
#
# - Are there any duplicate values in a given column (when this would be inappropriate?)
#
# - What are the mean, median, and mode of each column?
#
# - Are there any missing or null values?
#
#     - Do you want to fill in the missing value with a mean value?  A value of your choice?  Remove that row?
#
# - Identify any other inconsistent data (e.g. someone seems to be taking an action before they are born.)
#
# - Encode any categorical variables (e.g. with one-hot encoding.)
#
# ### Conclusions:
#
# - Are the data usable?  If not, find some new data!
#
# - Do you need to modify or correct the data in some way?
#
# - Is there any class imbalance?  (Categories that have many more items than other categories).

# %%
df_crm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         100 non-null    int64
#  1   Sales_Rep           100 non-null    object
#  2   Deal_Value          100 non-null    int64
#  3   Stage               100 non-null    object
#  4   Close_Date          100 non-null    datetime64[ns]
#  5   Lead_Source         100 non-null    object
#  6   Lead_Quality        100 non-null    object
#  7   Lead_Creation_Date  100 non-null    datetime64[ns]
#  8   Deal_Probability    100 non-null    float64
#  9   Deal_Notes          100 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(5)
# memory usage: 7.9+ KB

# %%
df_crm.describe()
# Out:
#         Customer_ID    Deal_Value                     Close_Date  \
# count    100.000000    100.000000                            100
# mean   53322.960000  24232.000000  2024-10-13 22:47:55.677164288
# min    10851.000000   1141.000000     2024-03-18 03:21:31.677030
# 25%    31392.500000  11671.000000  2024-09-21 03:21:31.677192960
# 50%    49836.000000  26211.000000  2024-10-06 03:21:31.677198080
# 75%    80078.500000  36453.500000  2025-01-27 03:21:31.677188096
# max    99733.000000  49217.000000     2025-01-27 03:21:31.677188
# std    26472.829103  14317.793856                            NaN
#
#                   Lead_Creation_Date  Deal_Probability
# count                            100        100.000000
# mean   2024-12-10 16:47:55.678318592          0.611000
# min       2024-11-01 03:21:31.678229          0.220000
# 25%    2024-11-21 03:21:31.678503936          0.400000
# 50%    2024-12-07 15:21:31.678352128          0.580000
# ...

# %%
df_gong_transcripts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Call_ID     50 non-null     int64
#  1   Timestamp   50 non-null     datetime64[ns]
#  2   Speaker     50 non-null     object
#  3   Transcript  50 non-null     object
#  4   Sentiment   50 non-null     object
#  5   Keywords    50 non-null     object
#  6   Duration    50 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 2.9+ KB

# %%
df_gong_transcripts.describe()
# Out:
#             Call_ID                      Timestamp    Duration
# count     50.000000                             50   50.000000
# mean   74997.200000  2025-02-08 14:38:54.737368320   90.520000
# min    50803.000000     2025-02-08 03:56:31.937338   13.000000
# 25%    62569.250000  2025-02-08 08:00:31.937416960   35.000000
# 50%    69611.500000  2025-02-08 13:25:31.937350400   92.000000
# 75%    88993.000000  2025-02-08 20:14:46.937459968  133.000000
# max    99950.000000     2025-02-09 01:36:31.937290  177.000000
# std    15862.430493                            NaN   53.187477

# %% [markdown]
# August Siu's Responses
#
# This week, you will do the same types of exercises as last week, but you should use your own datasets that you found last semester.
#
# ### Here are some types of analysis you can do  Use Google, documentation, and ChatGPT to help you:
#
# - Summarize the datasets using info() and describe()
#             A: See Above for both df_crm and df_gong_transcripts
#
# - Are there any duplicate rows?
#             A: No duplicate rows in either dataframe
#
# - Are there any duplicate values in a given column (when this would be inappropriate?)
#             A: There are many duplicate values within a given column.
#             In the df_crm,  based on which sales rep, base on what stage of the sale, the lead source and the quality of the leads can all repeat based on each deal.In the df_gong_transcript, based on the caller Id (phone number of client), speaker, sentiment, as we as duration and keyword could all possibly duplicate.These are all appropriate, all of these data duplicates can be respresent each interaaction sales reps have with clients.
#
# - What are the mean, median, and mode of each column?
#             A: Since many of the data are more qualitative data then quantitative data, it might seem the mean, median and mode might not be too useful.However, having access to the mean, mode and median of the timestamp, deal value allows data scientists to analzye how certain deals likely hood of closing might actually end faster or slower as well as how each reps' duration of calls might indicate how well each rep is doing.
#
# - Are there any missing or null values?
#             A: no missing nor null values
#
#     - Do you want to fill in the missing value with a mean value?  A value of your choice?  Remove that row?
#             A: N/A
#
# - Identify any other inconsistent data (e.g. someone seems to be taking an action before they are born.)
#             A: Yes, see below, line 201, when dates of deals created are after dates with deals closing.
#
# - Encode any categorical variables (e.g. with one-hot encoding.)

# %% [markdown]
# The following are codes for categorical variables with at least one-hot encoding. It is all commented out because since this dataset is on customber ID that is entirely independent of other infomrations, we do not nessearotly need an encoding part. If we can link the customber ID with other deals from the same cusotmber or client, then perhaps we can list the type of deals we have had exchanges with the client but as of now, every client has their own ID and is not duplicated.

# %%
# df_crm = pd.get_dummies(df_crm, columns=["Lead_Source"])
# print(df_crm)

# %%
#df_crm

# %%
# ml_columns = ["Lead_Source_Direct Mail", "Lead_Source_Email Campaign", "Lead_Source_Referral", "Lead_Source_Social Media", "Lead_Source_Web"]
# df_crm[ml_columns] = df_crm[ml_columns].astype(int)
# df_crm = df_crm[ml_columns]

# %%
df_crm
# Out:
#     Customer_ID Sales_Rep  Deal_Value          Stage  \
# 0         39256     Rep_B       24219    Closed Lost
# 1         28289     Rep_D       28759    Closed Lost
# 2         23434     Rep_D       27941       Proposal
# 3         98696     Rep_D       31606  Qualification
# 4         81482     Rep_B       48780       Proposal
# ..          ...       ...         ...            ...
# 95        45093     Rep_D       38042       Proposal
# 96        18675     Rep_B       35261       Proposal
# 97        37653     Rep_A       21733    Prospecting
# 98        84341     Rep_A       18089       Proposal
# 99        51245     Rep_D       14386  Qualification
#
#                    Close_Date     Lead_Source Lead_Quality  \
# 0  2024-12-13 03:21:31.677180     Direct Mail       Medium
# 1  2024-03-18 03:21:31.677030     Direct Mail       Medium
# 2  2025-01-27 03:21:31.677188     Direct Mail       Medium
# 3  2024-10-06 03:21:31.677198        Referral          Low
# ...

# %% [markdown]
# ### Conclusions:
#
# - Are the data usable?  If not, find some new data!
#         A: The data is , just have to maniputae it around to focused it around sales rep and compare sale reps quality of sales, duration, sentiment, stages and how long it took them to close the deal.
#
# - Do you need to modify or correct the data in some way?
#         A: Yes, see above answer.
#
# - Is there any class imbalance?  (Categories that have many more items than other categories).
#         A: There are many category items which we have to modify and alter to anazly our data, sentiment is one, quality of sales is on as well as stage.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

stage_counts = df_crm.groupby(['Sales_Rep', 'Stage']).size().reset_index(name='Count')

# Step 2: Pivot the data for easier plotting
pivot_stage = stage_counts.pivot(index='Sales_Rep', columns='Stage', values='Count').fillna(0)

# Step 3: Plot the results using a stacked bar chart
plt.figure(figsize=(10, 6))
pivot_stage.plot(kind='bar', stacked=True)

# Adding labels and title
plt.title('Comparison of Sales Reps by Stage', fontsize=16)
plt.xlabel('Sales Rep', fontsize=12)
plt.ylabel('Count of Deals in Each Stage', fontsize=12)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.legend(title="Stages")
plt.tight_layout()
plt.show()

# %%
df_crm['Lead_Creation_Date'] = pd.to_datetime(df_crm['Lead_Creation_Date'])
df_crm['Close_Date'] = pd.to_datetime(df_crm['Close_Date'])

df_crm['Days_To_Close'] = (df_crm['Close_Date']-df_crm['Lead_Creation_Date']).dt.days
df_crm
# Out:
#     Customer_ID Sales_Rep  Deal_Value          Stage  \
# 0         39256     Rep_B       24219    Closed Lost
# 1         28289     Rep_D       28759    Closed Lost
# 2         23434     Rep_D       27941       Proposal
# 3         98696     Rep_D       31606  Qualification
# 4         81482     Rep_B       48780       Proposal
# ..          ...       ...         ...            ...
# 95        45093     Rep_D       38042       Proposal
# 96        18675     Rep_B       35261       Proposal
# 97        37653     Rep_A       21733    Prospecting
# 98        84341     Rep_A       18089       Proposal
# 99        51245     Rep_D       14386  Qualification
#
#                    Close_Date     Lead_Source Lead_Quality  \
# 0  2024-12-13 03:21:31.677180     Direct Mail       Medium
# 1  2024-03-18 03:21:31.677030     Direct Mail       Medium
# 2  2025-01-27 03:21:31.677188     Direct Mail       Medium
# 3  2024-10-06 03:21:31.677198        Referral          Low
# ...

# %%
df_crm = df_crm[df_crm['Days_To_Close'] >= 0]
df_crm
# Out:
#     Customer_ID Sales_Rep  Deal_Value          Stage  \
# 0         39256     Rep_B       24219    Closed Lost
# 2         23434     Rep_D       27941       Proposal
# 6         87397     Rep_B       45129  Qualification
# 8         14165     Rep_C       43348    Closed Lost
# 12        40495     Rep_B       48724    Prospecting
# 13        76237     Rep_B       23236    Prospecting
# 16        83563     Rep_A       13556     Closed Won
# 17        36062     Rep_A       13465    Prospecting
# 23        87236     Rep_D       19254  Qualification
# 25        10851     Rep_C       17371    Prospecting
# 26        30926     Rep_A        5940  Qualification
# 27        65392     Rep_A       30041       Proposal
# 32        54118     Rep_D       36427    Closed Lost
# 33        23396     Rep_B        1967       Proposal
# 35        59797     Rep_A       16491    Closed Lost
# 36        22676     Rep_C       11899     Closed Won
# 40        44671     Rep_B       15008       Proposal
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

stage_counts = df_crm.groupby(['Sales_Rep', 'Stage']).size().reset_index(name='Count')

pivot_stage = stage_counts.pivot(index='Sales_Rep', columns='Stage', values='Count').fillna(0)

plt.figure(figsize=(10, 6))
pivot_stage.plot(kind='bar', stacked=False)  # Change stacked=True to stacked=False

plt.title('Comparison of Sales Reps by Stage', fontsize=16)
plt.xlabel('Sales Rep', fontsize=12)
plt.ylabel('Count of Deals in Each Stage', fontsize=12)
plt.xticks(rotation=45, ha='right')

plt.legend(title="Stages")
plt.tight_layout()
plt.show()

# %%
df_crm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         34 non-null     int64
#  1   Sales_Rep           34 non-null     object
#  2   Deal_Value          34 non-null     int64
#  3   Stage               34 non-null     object
#  4   Close_Date          34 non-null     datetime64[ns]
#  5   Lead_Source         34 non-null     object
#  6   Lead_Quality        34 non-null     object
#  7   Lead_Creation_Date  34 non-null     datetime64[ns]
#  8   Deal_Probability    34 non-null     float64
#  9   Deal_Notes          34 non-null     object
#  10  Days_To_Close       34 non-null     int64
# dtypes: datetime64[ns](2), float64(1), int64(3), object(5)
# memory usage: 3.2+ KB

# %% [markdown]
# # 4. Storytelling With Data graph

# %% [markdown]
# Just like last week: choose any graph in the Introduction of Storytelling With Data. Use matplotlib to reproduce it in a rough way. I don't expect you to spend an enormous amount of time on this; I understand that you likely will not have time to re-create every feature of the graph. However, if you're excited about learning to use matplotlib, this is a good way to do that. You don't have to duplicate the exact values on the graph; just the same rough shape will be enough.  If you don't feel comfortable using matplotlib yet, do the best you can and write down what you tried or what Google searches you did to find the answers.

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Sales_Rep', y='Days_To_Close', data=df_crm, ci=None, estimator='sum', palette='viridis')
plt.title('Total Days to Close by Sales Rep')
plt.xlabel('Sales Rep')
plt.ylabel('Total Days to Close')
plt.show()
# Out:
# /var/folders/dj/98fc07q174v2g56bdt5hzd8h0000gn/T/ipykernel_15674/2629218807.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Sales_Rep', y='Days_To_Close', data=df_crm, ci=None, estimator='sum', palette='viridis')
# /var/folders/dj/98fc07q174v2g56bdt5hzd8h0000gn/T/ipykernel_15674/2629218807.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Sales_Rep', y='Days_To_Close', data=df_crm, ci=None, estimator='sum', palette='viridis')

# %%
print(df_gong_transcripts.columns)
# Out:
# Index(['Call_ID', 'Timestamp', 'Speaker', 'Transcript', 'Sentiment',
#        'Keywords', 'Duration'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sentiment_counts = df_gong_transcripts.groupby(['Speaker', 'Sentiment']).size().reset_index(name='Count')

# Step 2: Pivot the data for easier plotting
pivot_sentiment = sentiment_counts.pivot(index='Speaker', columns='Sentiment', values='Count').fillna(0)

# Step 3: Plot the results using a stacked bar chart
plt.figure(figsize=(10, 6))
pivot_sentiment.plot(kind='bar', stacked=True)

# Adding labels and title
plt.title('Comparison of Sales Reps by Sentiment', fontsize=16)
plt.xlabel('Speaker', fontsize=12)
plt.ylabel('Count of Sentiments in Each Sales Rep', fontsize=12)
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.legend(title="Sentiment")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sentiment_counts = df_gong_transcripts.groupby(['Speaker','Sentiment']).size().reset_index(name='Count')

pivot_sentiment = sentiment_counts.pivot(index='Speaker', columns='Sentiment', values='Count').fillna(0)

plt.figure(figsize=(10, 6))
pivot_sentiment.plot(kind='bar', stacked=False)  # Change stacked=True to stacked=False

plt.title('Comparison of Speaker by Sentiment', fontsize=16)
plt.xlabel('Speaker', fontsize=12)
plt.ylabel('Count of Sentiment in Each Speaker', fontsize=12)
plt.xticks(rotation=45, ha='right')

plt.legend(title="Sentiment")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Speaker', y='Duration', data=df_gong_transcripts, ci=None, estimator='sum', palette='viridis')
plt.title('Total Minutes on a Call')
plt.xlabel('Speaker')
plt.ylabel('Total Minutes')
plt.show()
# Out:
# /var/folders/dj/98fc07q174v2g56bdt5hzd8h0000gn/T/ipykernel_15674/3613010362.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Speaker', y='Duration', data=df_gong_transcripts, ci=None, estimator='sum', palette='viridis')
# /var/folders/dj/98fc07q174v2g56bdt5hzd8h0000gn/T/ipykernel_15674/3613010362.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Speaker', y='Duration', data=df_gong_transcripts, ci=None, estimator='sum', palette='viridis')

# %%
stage_vs_deal = df_crm.groupby(['Sales_Rep', 'Stage'])['Deal_Value'].sum().reset_index()

heatmap_stage_deal = stage_vs_deal.pivot(index='Sales_Rep', columns='Stage', values='Deal_Value')

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_stage_deal, annot=True, cmap='coolwarm', cbar=True)
plt.title("Sales Rep Performance by Deal Value and Stage")
plt.xlabel("Sales Stage")
plt.ylabel("Sales Rep")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Create a copy of the DataFrame
df_crm_no_lost = df_crm.copy()

# Get the index of rows where Stage is 'Closed Lost'
indices_to_drop = df_crm_no_lost[df_crm_no_lost['Stage'] == 'Closed Lost'].index

# Drop those rows in the copy
df_crm_no_lost.drop(indices_to_drop, inplace=True)

df_crm_no_lost
# Out:
#     Customer_ID Sales_Rep  Deal_Value          Stage  \
# 2         23434     Rep_D       27941       Proposal
# 6         87397     Rep_B       45129  Qualification
# 12        40495     Rep_B       48724    Prospecting
# 13        76237     Rep_B       23236    Prospecting
# 16        83563     Rep_A       13556     Closed Won
# 17        36062     Rep_A       13465    Prospecting
# 23        87236     Rep_D       19254  Qualification
# 25        10851     Rep_C       17371    Prospecting
# 26        30926     Rep_A        5940  Qualification
# 27        65392     Rep_A       30041       Proposal
# 33        23396     Rep_B        1967       Proposal
# 36        22676     Rep_C       11899     Closed Won
# 40        44671     Rep_B       15008       Proposal
# 43        80284     Rep_B       11789  Qualification
# 46        20328     Rep_D       26586    Prospecting
# 51        57400     Rep_B       46651       Proposal
# 52        85674     Rep_A       48874     Closed Won
# ...

# %%
closingdays_vs_prob = df_crm.groupby(['Sales_Rep', 'Days_To_Close'])['Deal_Probability'].sum().reset_index()

heatmap_closing = closingdays_vs_prob.pivot(index='Sales_Rep', columns='Days_To_Close', values='Deal_Probability')

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_closing, annot=True, cmap='coolwarm', cbar=True)
plt.title("Sales Rep Performance by Days to Close and Deal's probability")
plt.xlabel("Sales Days to Close")
plt.ylabel("Sales Rep")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
closingdays_vs_prob = df_crm_no_lost.groupby(['Sales_Rep', 'Days_To_Close'])['Deal_Probability'].sum().reset_index()

heatmap_closing = closingdays_vs_prob.pivot(index='Sales_Rep', columns='Days_To_Close', values='Deal_Probability')

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_closing, annot=True, cmap='coolwarm', cbar=True)
plt.title("Sales Rep Performance by Days to Close and Deal's probability")
plt.xlabel("Sales Days to Close")
plt.ylabel("Sales Rep")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
stage_vs_deal = df_crm_no_lost.groupby(['Sales_Rep', 'Stage'])['Deal_Value'].sum().reset_index()

heatmap_stage_deal = stage_vs_deal.pivot(index='Sales_Rep', columns='Stage', values='Deal_Value')

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_stage_deal, annot=True, cmap='coolwarm', cbar=True)
plt.title("Sales Rep Performance by Deal Value and Stage")
plt.xlabel("Sales Stage")
plt.ylabel("Sales Rep")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
